# %% [markdown]
# <a href="https://colab.research.google.com/github/PosgradoMNA/actividades-de-aprendizaje-valeriaarh/blob/main/Avance02_Equipo10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Equipo 10:
#
# Evelyn Aylin Rendón Medina A01748750
#
# Valeria Alejandra Ramírez Herrera A01240716

# %% [markdown]
# 1. Identificar una metodología que vas a usar durante la realización del proyecto
#   Metodología SEMMA
# 2. Escribe los pasos estándares en un máximo de 3 oraciones, por cada fase
#
#   a. Muestreo - En este paso se hace la captura y la estructura de los datos. El tamano de nuestro data set debe ser representativo y procesable.
#
#   b. Exploración - Lograr el entendimiento de los datos con técnicas como la visualización o el agrupamiento, para encontrar tendencias o relaciones que nos den una visión general de los datos y algún fenómeno subyacente.
#
#   c. Modificación - Se trabajan los datos seleccionando las variables que nos sean útiles para alcanzar los resultados. En esta fase se hace la transformación de los datos.
#
#   d. Modelado - Se determina el modelo que mejor predice las variables de salida a partir de las variables de entrada. Y mostrar la relación de las variables para predecir su comportamiento.
#
#   e. Evaluación - Se verifica la fiabilidad, veracidad y utilidad del modelo.
#
# 3. Documenta el proceso en jupyter notebook.
#
# 4. Una metodología sencilla, que puedan usar en su proyecto.
#   Metodología SEMMA
# 5. Crear / dibujar una metodología posible  usando las herramientas en miro.com.
#   Adjunto
#   ![Metodologia_SEMMA.png](data:image/png;base64,...)

# %% [markdown]
# Referencia:
# # ![image.png](data:image/png;base64,...)
