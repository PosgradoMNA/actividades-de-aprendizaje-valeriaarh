# %% [markdown]
# <a href="https://colab.research.google.com/github/PosgradoMNA/actividades-de-aprendizaje-valeriaarh/blob/main/Modulo4_IBM_Valeria_A01240716__Apuntes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Módulo 4 - IBM - Notas
#
# Valeria Ramirez - A01240716

# %% [markdown]
# **Nota**: Examen y progreso del curso al final del documento

# %% [markdown]
# **Tema 1** - Leer archivos

# %%
# Se hace la importación de los datos en base al comando import y la liga de donde

import urllib.request
url = 'https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-PY0101EN-SkillsNetwork/labs/Module%204/data/example1.txt'
filename = 'Example1.txt'
urllib.request.urlretrieve(url, filename)

## Download Example file
# !wget -O /resources/data/Example1.txt https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-PY0101EN-SkillsNetwork/labs/Module%204/data/example1.txt
# Out:
# /resources/data/Example1.txt: No such file or directory

# %% [markdown]
# Para la lectura de archivos, primero se asina un objeto y con la función open done se pone el path del archivo que quieres abrir ya sea web o local y el parámetro que necesites en este caso se necesita 'r' para la lectura del archivo.
#
# ![Screen Shot 2022-09-27 at 20.56.28.png](data:image/png;base64,...)

# %%
# se hace la lectura del archivo y se imprime el nombre del mismo
example1 = "Example1.txt"
file1 = open(example1, "r")

file1.name
# Out:
# 'Example1.txt'

# %%
#Se imprime contenido del archivo
FileContent = file1.read()
FileContent
print(FileContent)
# Out:
# This is line 1
# This is line 2
# This is line 3

# %%
#Se cierra archivo
file1.close()

# %% [markdown]
# Existe una mejor manera para abrir un archivo con el statement with y asignar el nombre de una variable.
#
# ![Screen Shot 2022-09-27 at 21.05.33.png](data:image/png;base64,...)

# %%
#El .read() te va a leer la cantidad de caracteres que coloque dentro del paréntesis
with open(example1, "r") as file1:
    print(file1.read(4))
    print(file1.read(4))
    print(file1.read(7))
    print(file1.read(15))
# Out:
# This
#  is
# line 1
#
# This is line 2

# %% [markdown]
# ![Screen Shot 2022-09-27 at 21.07.20.png](data:image/png;base64,...)

# %%
# object = open(file path, mode like r for reading, w for writing, a for appending)
#open function to open the file

#close() to close the file, always close the file

#Printing the file content is possible even after the file is closed

#readlines(##) to read the characters of the lines

# %% [markdown]
# **Tema 2** - para escribir en archivos 'w'
#
# ![Screen Shot 2022-09-27 at 20.13.08.png](data:image/png;base64,...)

# %% [markdown]
# Uso del parámetro 'w' como writing
#
# Se crea un archivo que se va al directorio.
# con el parámetro 'w' como writing se usa para escribir dentro del archivo creado.
#
# Se define un argumento y se escribe la línea que se anadirá al archivo, y cada que se manda llamar el argumento agrega una nueva línea de texto en caso de que se requiera, y se manda cerrar el arhivo
#
#
# ![Screen Shot 2022-09-27 at 20.18.28.png](data:image/png;base64,...)
#
#
# Para evitar lo anterior se puede crear un loop de la función for, así que si se definen X cantidad de líneas, el loop correrá hasta que todas las líneas hayan sido escritas y cerrará el archivo.

# %%
exmp2 = 'Example2.txt' #se abre y escribe en el archivo
with open(exmp2, 'w') as writefile:
    writefile.write("This is line A")

# %%
with open(exmp2, 'r') as testwritefile: #Aqui se lee lo que se escribió
    print(testwritefile.read())
# Out:
# This is line A

# %%
with open(exmp2, 'w') as writefile: # se escriben algunas lineas en el archivo con el comando 'w', y se asigna la variable writefile
    writefile.write("This is line A\n")
    writefile.write("This is line B\n")

# %%
# se hace la prueba de que se hayan escrito las lineas 

with open(exmp2, 'r') as testwritefile:
    print(testwritefile.read())
# Out:
# This is line A
# This is line B

# %%
# de la línea anterior se visalizan las lineas en el archivo que se agregaron

Lines = ["This is line A\n", "This is line B\n", "This is line C\n"]
Lines
# Out:
# ['This is line A\n', 'This is line B\n', 'This is line C\n']

# %%
# Las líneas se agregan al archivo, al esribirlas con 'w'

with open('Example2.txt', 'w') as writefile:
    for line in Lines:
        print(line)
        writefile.write(line)
# Out:
# This is line A
#
# This is line B
#
# This is line C

# %%
#Se verifica que las líneas se hayan escrito en el archico
# Verify if writing to file is successfully executed

with open('Example2.txt', 'r') as testwritefile:
    print(testwritefile.read())
# Out:
# This is line A
# This is line B
# This is line C

# %%
#Se reemplaza el texto original con las líneas nuevas agregadas y el comando Overwrite
with open('Example2.txt', 'w') as writefile:
    writefile.write("Overwrite\n")
with open('Example2.txt', 'r') as testwritefile:
    print(testwritefile.read())
# Out:
# Overwrite

# %% [markdown]
# Entra el parámetro 'a' o Appending, donde se podrá escribir líneas adicionales sin cambiar los datos iniciales. Ejercicio a continuación

# %%
#Se agregan las lineas de C, D y E al archivo inicial Example2, pero sin borrar las líneas A y B que ya estaban

# Write a new line to text file

with open('Example2.txt', 'a') as testwritefile:
    testwritefile.write("This is line C\n")
    testwritefile.write("This is line D\n")
    testwritefile.write("This is line E\n")

#y se verifica que se hayan escrito sin quitar la información anterior

with open('Example2.txt', 'r') as testwritefile:
    print(testwritefile.read())
# Out:
# Overwrite
# This is line C
# This is line D
# This is line E
# This is line C
# This is line D
# This is line E

# %% [markdown]
# Existen parámetros adicionales que pueden hacer el Apendant y la escritura de archivos más eficiente:
# +r: puedes leer y escribir en el fichero/archivo - no lo corrompe
#
# +w: se puede escribir y leer el fichero/archivo - este hay que usarlo con cuidado porque sí puede truncar el archivo, ya que sobreescribe los datos que ya existían y los borra
#
# +a: puedes agregar y leer en un archvo/fichero, es capaz de crear un nuevo archivo incluso si no existe.

# %%
with open('Example2.txt', 'a+') as testwritefile:
    print("Initial Location: {}".format(testwritefile.tell()))
    
    data = testwritefile.read()
    if (not data):  #si no hay datos regresa un error, pero como si hay datos los muestra
            print('Read nothing') 
    else: 
            print(testwritefile.read())
            
    testwritefile.seek(0,0) # move 0 bytes from beginning.
    
    print("\nNew Location : {}".format(testwritefile.tell()))
    data = testwritefile.read()
    if (not data): 
            print('Read nothing') 
    else: 
            print(data)
    
    print("Location after read: {}".format(testwritefile.tell()) )
# Out:
# Initial Location: 115
# Read nothing
#
# New Location : 0
# Overwrite
# This is line C
# This is line D
# This is line E
# This is line C
# This is line D
# This is line E
# This is line E
#
# Location after read: 115

# %%
#Aquí se hace un ejemplo del uso de +r donde puedes leer y escribir al mismo tiempo
with open('Example2.txt', 'r+') as testwritefile: 
    data = testwritefile.readlines()
    testwritefile.seek(0,0) #write at beginning of file
   
    testwritefile.write("Line 1" + "\n")
    testwritefile.write("Line 2" + "\n")
    testwritefile.write("Line 3" + "\n")
    testwritefile.write("finished\n")
    
    testwritefile.truncate()
    testwritefile.seek(0,0)
    print(testwritefile.read())
# Out:
# Line 1
# Line 2
# Line 3
# finished

# %% [markdown]
# También se puede hacer copiar la información de un archivo a otro al leerlo primero y después escribir lo que tenías en ese en el otro así juntando la información de antes.
#
# OJO: se agrega la información del otro archivo no la sobreescribe.

# %%
#Se toma la información trabajada en el Example2.txt y se agrega/escribe en el Example3.txt dejando su información original
with open('Example2.txt','r') as readfile:
    with open('Example3.txt','w') as writefile:
          for line in readfile:
                writefile.write(line)

with open('Example3.txt','r') as testwritefile:
    print(testwritefile.read())
# Out:
# Line 1
# Line 2
# Line 3
# finished

# %% [markdown]
# Ejercicio Lab 4.2
#
# Con los datos actuales currentMem, se necesita remover los miembro que tienen un 'no' como activos pero llevando el registro de quienes son los miembros que han sido removidos y agregarlos en el exMem

# %%
#Código ya dado para correr 

from random import randint as rnd

memReg = 'members.txt'
exReg = 'inactive.txt'
fee =('yes','no')

def genFiles(current,old):
    with open(current,'w+') as writefile: 
        writefile.write('Membership No  Date Joined  Active  \n')
        data = "{:^13}  {:<11}  {:<6}\n"

        for rowno in range(20):
            date = str(rnd(2015,2020))+ '-' + str(rnd(1,12))+'-'+str(rnd(1,25))
            writefile.write(data.format(rnd(10000,99999),date,fee[rnd(0,1)]))


    with open(old,'w+') as writefile: 
        writefile.write('Membership No  Date Joined  Active  \n')
        data = "{:^13}  {:<11}  {:<6}\n"
        for rowno in range(3):
            date = str(rnd(2015,2020))+ '-' + str(rnd(1,12))+'-'+str(rnd(1,25))
            writefile.write(data.format(rnd(10000,99999),date,fee[1]))


genFiles(memReg,exReg)

# %% [markdown]
# Aquí se hace la limpieza de los datos tal como lo pide la instrucción

# %%
def cleanFiles(currentMem,exMem): #se define la función para hacer la limpieza que involucra las variables dadas
    with open(currentMem,'r+') as writeFile: #Se lee y se escribe en el mismo archivo sin truncarlo
        with open(exMem,'a+') as appendFile: #Se crea un nuevo archivo y se lee
            
            writeFile.seek(0)
            members = writeFile.readlines()
            
            header = members[0] #Se remueven los headers del archivo ya que no son relevantes para los datos
            members.pop(0)
                
            inactive = [member for member in members if ('no' in member)] #Se define cuáles son los miebros activos y cuando 'no'
            
            writeFile.seek(0) 
            writeFile.write(header)

            #se hace el loop para saber cuáles miembros están o no activos y se escribe en el archivo correspondiente haciendo la filtración de cada uno
            for member in members: 
                if (member in inactive):
                    appendFile.write(member)
                else:
                    writeFile.write(member)      
            writeFile.truncate()
                
memReg = 'members.txt'
exReg = 'inactive.txt'
cleanFiles(memReg,exReg)

# Se despliega la información de cada archivo de los miembros activos o no

headers = "Membership No  Date Joined  Active  \n"

with open(memReg,'r') as readFile:
    print("Active Members: \n\n")
    print(readFile.read())
    
with open(exReg,'r') as readFile:
    print("Inactive Members: \n\n")
    print(readFile.read())
# Out:
# Active Members:
#
#
# Membership No  Date Joined  Active
#     56698      2016-2-3     yes
#     35797      2017-8-1     yes
#     47397      2019-3-1     yes
#     39737      2019-2-10    yes
#     77023      2017-12-12   yes
#     37186      2017-6-11    yes
#     12890      2015-9-2     yes
#     86199      2015-6-3     yes
#     25777      2015-4-11    yes
#     87370      2020-7-5     yes
#
# Inactive Members:
#
#
# Membership No  Date Joined  Active
#     16109      2015-11-19   no
#     79767      2019-3-10    no
#     14205      2015-3-19    no
#     74370      2016-11-24   no
#     78662      2015-10-21   no
#     47045      2018-4-18    no
#     72243      2016-1-16    no
#     43472      2018-11-23   no
#     61311      2017-9-20    no
#     64852      2019-10-4    no
#     58329      2015-3-18    no
#     30593      2020-9-2     no
#     94643      2016-12-13   no

# %% [markdown]
# **Tema 3** - Cargar datos con Pandas
#
# Las dependencias o librerías son códigos previamente escritos que ayudan para resolver problemas, una muy popular es Pandas para análisis de datos
#
# primero se hace la importacion y se puede abreviar
#
# se usa el data frame, libreria y la función que se desea usar.
#
# ![Screen Shot 2022-09-27 at 22.11.34.png](data:image/png;base64,...)
#
# Pandas es una librería que puede ser útil para trabajar datos incluso cuando están repetidos, si en un dataset quieres separar los valores únicos que se encuentran se puede usar el método Unique.

# %%
import pandas as pd

# %% [markdown]
# **Ejercicio 4.3**

# %%
#Instalación de librerías
# !pip install xlrd
# !pip install openpyxl
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
#Importación de Pandas
import pandas as pd

# %%
#Se hace la lectura del archivo CSV y se imprime el mismo

import pandas as pd
csv_path = 'https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-PY0101EN-SkillsNetwork/labs/Module%204/data/TopSellingAlbums.csv'
df = pd.read_csv(csv_path)
df.head()

#from pyodide.http import pyfetch


#filename = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-PY0101EN-SkillsNetwork/labs/Module%204/data/TopSellingAlbums.csv"

#async def download(url, filename):
 #   response = await pyfetch(url)
  #  if response.status == 200:
   #     with open(filename, "wb") as f:
    #        f.write(await response.bytes())


#await download(filename, "TopSellingAlbums.csv")
#df = pd.read_csv("TopSellingAlbums.csv")
# Out:
#             Artist                      Album  Released   Length  \
# 0  Michael Jackson                   Thriller      1982  0:42:19
# 1            AC/DC              Back in Black      1980  0:42:11
# 2       Pink Floyd  The Dark Side of the Moon      1973  0:42:49
# 3  Whitney Houston              The Bodyguard      1992  0:57:44
# 4        Meat Loaf            Bat Out of Hell      1977  0:46:33
#
#                          Genre  Music Recording Sales (millions)  \
# 0               pop, rock, R&B                              46.0
# 1                    hard rock                              26.1
# 2             progressive rock                              24.2
# 3               R&B, soul, pop                              27.4
# 4  hard rock, progressive rock                              20.6
#
#    Claimed Sales (millions) Released.1 Soundtrack  Rating
# 0                        65  30-Nov-82        NaN    10.0
# 1                        50  25-Jul-80        NaN     9.5
# ...

# %%
#Ahora se hace la lectura de la columna de 'Lenght.y se asigna a una variable
x = df[['Length']]
x
# Out:
#     Length
# 0  0:42:19
# 1  0:42:11
# 2  0:42:49
# 3  0:57:44
# 4  0:46:33
# 5  0:43:08
# 6  1:15:54
# 7  0:40:01

# %% [markdown]
# ![Screen Shot 2022-09-27 at 22.18.51.png](data:image/png;base64,...)

# %%
#Te da el tipo de variable de la columna 'Artist'

x = df[['Artist']]
type(x)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# Puedes segmentar tu data frame con las columnas que desees
# ![Screen Shot 2022-09-27 at 22.27.56.png](data:image/png;base64,...)

# %%
y = df[['Artist','Length','Genre']]
y
# Out:
#             Artist   Length                        Genre
# 0  Michael Jackson  0:42:19               pop, rock, R&B
# 1            AC/DC  0:42:11                    hard rock
# 2       Pink Floyd  0:42:49             progressive rock
# 3  Whitney Houston  0:57:44               R&B, soul, pop
# 4        Meat Loaf  0:46:33  hard rock, progressive rock
# 5           Eagles  0:43:08   rock, soft rock, folk rock
# 6         Bee Gees  1:15:54                        disco
# 7    Fleetwood Mac  0:40:01                    soft rock

# %% [markdown]
# Uso de funciones como
#
#   loc -se llama información de las columnas por nombre
#
#   iloc - se usan indices para llamar la información
#
#   ![Screen Shot 2022-09-27 at 22.32.18.png](data:image/png;base64,...)![Screen Shot 2022-09-27 at 22.32.25.png](data:image/png;base64,...)

# %%
#Ejemplo iloc - por índice
df.iloc[0,2]
# Out:
# 1982

# %%
#Ejemplo loc - por nombre

df.loc[0, 'Released']
# Out:
# 1982

# %% [markdown]
# A la vez se puede hacer la partición del Data set con las mismas funciones de loc y iloc.
#
# ![Screen Shot 2022-09-27 at 22.34.53.png](data:image/png;base64,...)![Screen Shot 2022-09-27 at 22.34.59.png](data:image/png;base64,...)

# %%
#Ejemplo iloc - por índice
df.iloc[0:2, 0:3]
# Out:
#             Artist          Album  Released
# 0  Michael Jackson       Thriller      1982
# 1            AC/DC  Back in Black      1980

# %%
#Ejemplo loc - por nombre
df.loc[0:2, 'Artist':'Released']
# Out:
#             Artist                      Album  Released
# 0  Michael Jackson                   Thriller      1982
# 1            AC/DC              Back in Black      1980
# 2       Pink Floyd  The Dark Side of the Moon      1973

# %% [markdown]
# **Quiz** - 4.3

# %%
# Use a variable q to store the column Rating as a dataframe
q= df[['Rating']]
q
# Out:
#    Rating
# 0    10.0
# 1     9.5
# 2     9.0
# 3     8.5
# 4     8.0
# 5     7.5
# 6     7.0
# 7     6.5

# %%
#Assign the variable q to the dataframe that is made up of the column Released and Artist:
q=df[['Released','Artist']]
q
# Out:
#    Released           Artist
# 0      1982  Michael Jackson
# 1      1980            AC/DC
# 2      1973       Pink Floyd
# 3      1992  Whitney Houston
# 4      1977        Meat Loaf
# 5      1976           Eagles
# 6      1977         Bee Gees
# 7      1977    Fleetwood Mac

# %%
#Access the 2nd row and the 3rd column of df:
df.iloc[1, 2]
# Out:
# 1980

# %%
#Use the following list to convert the dataframe index df to characters and assign it to df_new; 
#find the element corresponding to the row index a and column 'Artist'. Then select the rows a through d for the column 'Artist'

new_index=['a','b','c','d','e','f','g','h']

df_new=df
df_new.index=new_index
df_new.loc['a', 'Artist']
df_new.loc['a':'d', 'Artist']
# Out:
# a    Michael Jackson
# b              AC/DC
# c         Pink Floyd
# d    Whitney Houston
# Name: Artist, dtype: object

# %% [markdown]
# Resultados Review Questions Módulo 4 y Progreso
#
# ![Screen Shot 2022-09-27 at 22.29.02.png](data:image/png;base64,...)
#
#
# ![Screen Shot 2022-09-27 at 22.22.07.png](data:image/png;base64,...)![Screen Shot 2022-09-27 at 22.22.19.png](data:image/png;base64,...)![Screen Shot 2022-09-27 at 22.22.13.png](data:image/png;base64,...)![Screen Shot 2022-09-27 at 22.22.24.png](data:image/png;base64,...)
